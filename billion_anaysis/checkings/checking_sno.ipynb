# %%
with open(r"D:\pycharm_codes\billion_anaysis\checkings\check_input.txt", "r") as f, open(r"D:\pycharm_codes\billion_anaysis\checkings\check_output.txt", "w") as g:
    for i, line in enumerate(f, 1):
        g.write(f"{i}. {line}")

# %%
file = open(r"D:\pycharm_codes\billion_anaysis\checkings\check_input.txt", "r")
out = open(r"D:\pycharm_codes\billion_anaysis\checkings\check_output.txt", "w")

seen = set()

for line in file:
    line = line.strip()
    if line not in seen:
        out.write(line + "\n")
        seen.add(line)

# %%
seen = set()

for line in file:
    line = line.strip()

    if line.isalpha():
        if line not in seen:
            out.write(line + "\n")
            seen.add(line)
